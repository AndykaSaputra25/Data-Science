# %% [markdown]
# # <b>Import Libraries</b>

# %%
import pandas as pd
import mysql.connector as mysql

# %% [markdown]
# ## Sambungkan Koneksi MySql

# %%
koneksi = mysql.connect(host="localhost",
                       database="dsc",
                       user="root",
                       password="")

# %%
cursor = koneksi.cursor()
cursor.execute("SELECT * FROM offices")

table_offices = cursor.fetchall()
table_offices
# Out:
# [('1',
#   'San Francisco',
#   '+1 650 219 4782',
#   '100 Market Street',
#   'Suite 300',
#   'CA',
#   'USA',
#   '94080',
#   'NA'),
#  ('2',
#   'Boston',
#   '+1 215 837 0825',
#   '1550 Court Place',
#   'Suite 102',
#   'MA',
#   'USA',
#   '02107',
#   'NA'),
#  ('3',
#   'NYC',
#   '+1 212 555 3000',
#   '523 East 53rd Street',
#   'apt. 5A',
#   'NY',
#   'USA',
#   '10022',
#   'NA'),
#  ('4',
#   'Paris',
#   '+33 14 723 4404',
#   "43 Rue Jouffroy D'abbans",
#   None,
#   None,
#   'France',
#   '75017',
#   'EMEA'),
#  ('5',
#   'Tokyo',
#   '+81 33 224 5000',
#   '4-1 Kioicho',
#   None,
#   'Chiyoda-Ku',
#   'Japan',
#   '102-8578',
#   'Japan'),
#  ('6',
#   'Sydney',
#   '+61 2 9264 2451',
#   '5-11 Wentworth Avenue',
#   'Floor #2',
#   None,
#   'Australia',
#   'NSW 2010',
#   'APAC'),
#  ('7',
#   'London',
#   '+44 20 7877 2041',
#   '25 Old Broad Street',
#   'Level 7',
#   None,
#   'UK',
#   'EC2N 1HN',
#   'EMEA')]

# %%
#_Bentuk DataFram
data_offices = pd.DataFrame(columns = ["ID", 
                                         "Kota", 
                                         "Nomor", 
                                         "Alamat1", 
                                         "Alamat2", 
                                         "Ibu Kota", 
                                         "Negara",
                                       "Kode Pos",
                                       "teritori"],
                             data = table_offices)
#_Ubah Index
data_offices = data_offices.set_index('ID')
data_offices
# Out:
#              Kota             Nomor                   Alamat1    Alamat2  \
# ID
# 1   San Francisco   +1 650 219 4782         100 Market Street  Suite 300
# 2          Boston   +1 215 837 0825          1550 Court Place  Suite 102
# 3             NYC   +1 212 555 3000      523 East 53rd Street    apt. 5A
# 4           Paris   +33 14 723 4404  43 Rue Jouffroy D'abbans       None
# 5           Tokyo   +81 33 224 5000               4-1 Kioicho       None
# 6          Sydney   +61 2 9264 2451     5-11 Wentworth Avenue   Floor #2
# 7          London  +44 20 7877 2041       25 Old Broad Street    Level 7
#
#       Ibu Kota     Negara  Kode Pos teritori
# ID
# 1           CA        USA     94080       NA
# 2           MA        USA     02107       NA
# 3           NY        USA     10022       NA
# 4         None     France     75017     EMEA
# 5   Chiyoda-Ku      Japan  102-8578    Japan
# 6         None  Australia  NSW 2010     APAC
# 7         None         UK  EC2N 1HN     EMEA

# %% [markdown]
# # Create

# %%
cursor = koneksi.cursor()
sql = "INSERT INTO offices VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)"
data = ('8', 'Sidoarjo', '+621 81251', 'Sedati Agung', 'Rt 05', 'Jakarta', 'Indonesia', '61253', 'Republik')
cursor.execute(sql, data)
koneksi.commit()

# %% [markdown]
# # Read

# %%
cursor.execute("SELECT * FROM offices")
office = cursor.fetchall()
office
# Out:
# [('1',
#   'San Francisco',
#   '+1 650 219 4782',
#   '100 Market Street',
#   'Suite 300',
#   'CA',
#   'USA',
#   '94080',
#   'NA'),
#  ('2',
#   'Boston',
#   '+1 215 837 0825',
#   '1550 Court Place',
#   'Suite 102',
#   'MA',
#   'USA',
#   '02107',
#   'NA'),
#  ('3',
#   'NYC',
#   '+1 212 555 3000',
#   '523 East 53rd Street',
#   'apt. 5A',
#   'NY',
#   'USA',
#   '10022',
#   'NA'),
#  ('4',
#   'Paris',
#   '+33 14 723 4404',
#   "43 Rue Jouffroy D'abbans",
#   None,
#   None,
#   'France',
#   '75017',
#   'EMEA'),
#  ('5',
#   'Tokyo',
#   '+81 33 224 5000',
#   '4-1 Kioicho',
#   None,
#   'Chiyoda-Ku',
#   'Japan',
#   '102-8578',
#   'Japan'),
#  ('6',
#   'Sydney',
#   '+61 2 9264 2451',
#   '5-11 Wentworth Avenue',
#   'Floor #2',
#   None,
#   'Australia',
#   'NSW 2010',
#   'APAC'),
#  ('7',
#   'London',
#   '+44 20 7877 2041',
#   '25 Old Broad Street',
#   'Level 7',
#   None,
#   'UK',
#   'EC2N 1HN',
#   'EMEA'),
#  ('8',
#   'Sidoarjo',
#   '+621 81251',
#   'Sedati Agung',
#   'Rt 05',
#   'Jakarta',
#   'Indonesia',
#   '61253',
#   'Republik')]

# %% [markdown]
# # Update

# %%
# update
cursor = koneksi.cursor()
sql = "UPDATE offices SET postalCode = '12345' WHERE city = 'Sidoarjo'"
cursor.execute(sql)
koneksi.commit()

# %% [markdown]
# # Delete

# %%
cursor = koneksi.cursor()
sql = "DELETE FROM offices WHERE state = 'Jakarta'"
cursor.execute(sql)
koneksi.commit()

# %% [markdown]
# # Join

# %% [markdown]
# Studi Kasus:
# Saya ingin mengetahui sales yang melakukan penjualan paling banyak

# %%
cursor.execute("SELECT c.customerNumber, c.customerName, p.paymentDate, p.amount, \
        e.employeeNumber, CONCAT(e.firstName, ' ', e.lastName) as nama, e.email, e.jobTitle \
        FROM customers c  \
        INNER JOIN employees e ON e.employeeNumber = c.salesRepEmployeeNumber \
        INNER JOIN payments p ON p.customerNumber = c.customerNumber")
tbl_employee = cursor.fetchall()
dt = pd.DataFrame(columns=["Kode Cust", "Nama Cust", "Tanggal Bayar", "Jumlah Bayar","Kode Pegawai",  "Nama Pegawai", "Email", "Pekerjaan"], data=tbl_employee)
dt.head(10)
# Out:
#    Kode Cust                     Nama Cust Tanggal Bayar Jumlah Bayar  \
# 0        124  Mini Gifts Distributors Ltd.    2005-03-05    101244.59
# 1        124  Mini Gifts Distributors Ltd.    2004-08-28     85410.87
# 2        124  Mini Gifts Distributors Ltd.    2003-04-11     11044.30
# 3        124  Mini Gifts Distributors Ltd.    2005-04-16     83598.04
# 4        124  Mini Gifts Distributors Ltd.    2004-12-27     47142.70
# 5        124  Mini Gifts Distributors Ltd.    2004-11-02     55639.66
# 6        124  Mini Gifts Distributors Ltd.    2003-08-15    111654.40
# 7        124  Mini Gifts Distributors Ltd.    2004-03-26     43369.30
# 8        124  Mini Gifts Distributors Ltd.    2003-11-25     45084.38
# 9        129               Mini Wheels Co.    2004-12-08     26248.78
#
#    Kode Pegawai     Nama Pegawai                           Email  Pekerjaan
# 0          1165  Leslie Jennings  ljennings@classicmodelcars.com  Sales Rep
# 1          1165  Leslie Jennings  ljennings@classicmodelcars.com  Sales Rep
# 2          1165  Leslie Jennings  ljennings@classicmodelcars.com  Sales Rep
# 3          1165  Leslie Jennings  ljennings@classicmodelcars.com  Sales Rep
# 4          1165  Leslie Jennings  ljennings@classicmodelcars.com  Sales Rep
# 5          1165  Leslie Jennings  ljennings@classicmodelcars.com  Sales Rep
# 6          1165  Leslie Jennings  ljennings@classicmodelcars.com  Sales Rep
# 7          1165  Leslie Jennings  ljennings@classicmodelcars.com  Sales Rep
# 8          1165  Leslie Jennings  ljennings@classicmodelcars.com  Sales Rep
# 9          1165  Leslie Jennings  ljennings@classicmodelcars.com  Sales Rep

# %% [markdown]
# # Preprocessing

# %% [markdown]
# Membersihkan data yang memiliki nilai yang kosong/hilang

# %%
import numpy as np
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 273 entries, 0 to 272
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Kode Cust      273 non-null    int64
#  1   Nama Cust      273 non-null    object
#  2   Tanggal Bayar  273 non-null    object
#  3   Jumlah Bayar   273 non-null    object
#  4   Kode Pegawai   273 non-null    int64
#  5   Nama Pegawai   273 non-null    object
#  6   Email          273 non-null    object
#  7   Pekerjaan      273 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 10.7+ KB

# %%
dt.isnull().sum()
# Out:
# Kode Cust        0
# Nama Cust        0
# Tanggal Bayar    0
# Jumlah Bayar     0
# Kode Pegawai     0
# Nama Pegawai     0
# Email            0
# Pekerjaan        0
# dtype: int64

# %% [markdown]
# Mendeteksi outlier pada data

# %%
dt["Nama Cust"].value_counts()
# Out:
# Euro+ Shopping Channel                13
# Mini Gifts Distributors Ltd.           9
# Danish Wholesale Imports               4
# Muscle Machine Inc                     4
# Down Under Souveniers, Inc             4
#                                       ..
# Australian Collectables, Ltd           2
# Collectable Mini Designs Co.           1
# The Sharp Gifts Warehouse              1
# Bavarian Collectables Imports, Co.     1
# King Kong Collectables, Co.            1
# Name: Nama Cust, Length: 98, dtype: int64

# %%
dt["Tanggal Bayar"].value_counts()
# Out:
# 2003-11-18    3
# 2003-12-09    3
# 2004-06-21    3
# 2003-11-24    3
# 2003-12-07    2
#              ..
# 2003-10-28    1
# 2004-07-03    1
# 2004-09-30    1
# 2004-09-07    1
# 2005-01-29    1
# Name: Tanggal Bayar, Length: 232, dtype: int64

# %%
dt['Kode Pegawai'].value_counts()
# Out:
# 1370    29
# 1401    27
# 1504    21
# 1501    21
# 1165    21
# 1323    20
# 1337    19
# 1286    17
# 1611    16
# 1216    15
# 1188    14
# 1621    14
# 1612    14
# 1166    13
# 1702    12
# Name: Kode Pegawai, dtype: int64

# %%
dt['Nama Pegawai'].value_counts()
# Out:
# Gerard Hernandez    29
# Pamela Castillo     27
# Larry Bott          21
# Barry Jones         21
# Leslie Jennings     21
# George Vanauf       20
# Loui Bondur         19
# Foon Yue Tseng      17
# Andy Fixter         16
# Steve Patterson     15
# Julie Firrelli      14
# Mami Nishi          14
# Peter Marsh         14
# Leslie Thompson     13
# Martin Gerard       12
# Name: Nama Pegawai, dtype: int64

# %%
dt['Pekerjaan'].value_counts() # ada 3 data beda, harusnya sama
# Out:
# Sales Rep    192
# sls rep       48
# sale rep      33
# Name: Pekerjaan, dtype: int64

# %%
dt['Pekerjaan'] = dt['Pekerjaan'].replace(["sls rep","sale rep"],"Sales Rep")
dt['Pekerjaan'].value_counts()
# Out:
# Sales Rep    273
# Name: Pekerjaan, dtype: int64

# %%
# convert Jumlah Bayar to float
dt["Jumlah Bayar"] = dt['Jumlah Bayar'].astype(float)

# convert Kode ke string
dt['Kode Cust'] = dt['Kode Cust'].astype('str')
dt['Kode Pegawai'] = dt['Kode Pegawai'].astype('str')

# %%
dt.boxplot(["Jumlah Bayar"])

# %%
dt.describe()
# Out:
#         Jumlah Bayar
# count     273.000000
# mean    32431.645531
# std     20997.116917
# min       615.450000
# 25%     16909.840000
# 50%     32077.440000
# 75%     45352.470000
# max    120166.580000

# %%
dt._get_numeric_data()
# Out:
#      Jumlah Bayar
# 0       101244.59
# 1        85410.87
# 2        11044.30
# 3        83598.04
# 4        47142.70
# ..            ...
# 268      33145.56
# 269      22162.61
# 270      57131.92
# 271       3474.66
# 272      47513.19
#
# [273 rows x 1 columns]

# %%
from scipy import stats

hasil_zscore = np.abs(stats.zscore(dt._get_numeric_data()))
print(hasil_zscore)
# Out:
# [[3.28327566]
#  [2.52780054]
#  [1.02045555]
#  [2.44130488]
#  [0.70190932]
#  [1.10732522]
#  [3.77995947]
#  [0.52186889]
#  [0.60370059]
#  [0.29500339]
#  [0.40592908]
#  [0.75834151]
#  [1.43126732]
#  [0.87372164]
#  [0.94182968]
#  [0.2978957 ]
#  [2.534874  ]
#  [0.684683  ]
#  [1.29396532]
#  [0.11616008]
#  [0.94750324]
#  [0.87031116]
#  [0.0100357 ]
#  [0.04371634]
#  [1.36228808]
#  [0.854593  ]
#  [0.34109844]
#  [1.38267157]
#  [1.33433348]
#  [2.28753526]
#  [0.54287699]
#  [0.5715616 ]
#  [1.18106007]
#  [0.17361942]
#  [0.98232566]
#  [0.57620218]
#  [0.8932463 ]
#  [1.33631119]
#  [1.15104713]
#  [0.40962154]
#  [0.95983606]
#  [0.43412129]
#  [0.10375845]
#  [0.19604413]
#  [0.01186454]
#  [0.94954393]
#  [1.28030794]
#  [1.24793707]
#  [0.12980214]
#  [1.47554927]
#  [1.08656484]
#  [1.25937103]
#  [1.26788303]
#  [0.71472648]
#  [0.51064391]
#  [0.66597572]
#  [0.82886569]
#  [0.87639548]
#  [1.05960268]
#  [1.09711988]
#  [0.10200457]
#  [1.07133913]
#  [0.75979336]
#  [1.25780599]
#  [0.57814887]
#  [1.26008762]
#  [0.35942169]
#  [0.46898522]
#  [1.28524009]
#  [0.57107059]
#  [0.16037624]
#  [0.45013427]
#  [0.74059273]
#  [0.33044465]
#  [0.51366277]
#  [0.49570405]
#  [0.27232389]
#  [0.00916928]
#  [0.23289388]
#  [1.46725871]
#  [0.48376386]
#  [0.83944935]
#  [0.1379062 ]
#  [0.18755359]
#  [0.36035596]
#  [0.45867152]
#  [0.19543097]
#  [0.05548715]
#  [0.24314259]
#  [0.15016374]
#  [0.47274639]
#  [0.17466577]
#  [1.20489703]
#  [0.06340089]
#  [1.23101039]
#  [0.73475026]
#  [0.29236247]
#  [1.26593539]
#  [0.64710468]
#  [0.31483484]
#  [0.40779795]
#  [0.81985694]
#  [0.34737271]
#  [1.45385706]
#  [0.89595258]
#  [0.04539871]
#  [0.79245682]
#  [0.88601109]
#  [0.07329128]
#  [0.49591685]
#  [1.51804782]
#  [0.78707426]
#  [1.39943555]
#  [0.35720069]
#  [0.3837186 ]
#  [0.71303696]
#  [1.38226405]
#  [0.04787697]
#  [0.81630905]
#  [0.03406304]
#  [0.48996703]
#  [1.1785255 ]
#  [1.38162618]
#  [0.71958653]]

# %%
hasil_zscore.shape
# Out:
# (273, 1)

# %%
outlier = dt[(hasil_zscore > 3).all(axis=1)]
print(outlier.shape)
# Out:
# (5, 8)

# %%
outlier
# Out:
#     Kode Cust                     Nama Cust Tanggal Bayar  Jumlah Bayar  \
# 0         124  Mini Gifts Distributors Ltd.    2005-03-05     101244.59
# 6         124  Mini Gifts Distributors Ltd.    2003-08-15     111654.40
# 129       141        Euro+ Shopping Channel    2004-12-31     116208.40
# 131       141        Euro+ Shopping Channel    2005-03-18     120166.58
# 249       148       Dragon Souveniers, Ltd.    2003-12-26     105743.00
#
#     Kode Pegawai      Nama Pegawai                           Email  Pekerjaan
# 0           1165   Leslie Jennings  ljennings@classicmodelcars.com  Sales Rep
# 6           1165   Leslie Jennings  ljennings@classicmodelcars.com  Sales Rep
# 129         1370  Gerard Hernandez  ghernande@classicmodelcars.com  Sales Rep
# 131         1370  Gerard Hernandez  ghernande@classicmodelcars.com  Sales Rep
# 249         1621        Mami Nishi     mnishi@classicmodelcars.com  Sales Rep

# %%
import seaborn as sns
sns.set(style="whitegrid")

# %%
dt_2 = pd.DataFrame([])

dt_2["Keterangan"] = ["Tidak ada outlier","Outlier"]
dt_2["Jumlah Observasi"] = [273, 5]

dt_2
# Out:
#           Keterangan  Jumlah Observasi
# 0  Tidak ada outlier               273
# 1            Outlier                 5

# %%
plot=sns.barplot(x="Keterangan",y="Jumlah Observasi",data=dt_2)

# %% [markdown]
# Melakukan normalisasi nilai pada data

# %%
from sklearn import preprocessing

# %%
# min-max normalization
dt["Jumlah Bayar"] = (dt["Jumlah Bayar"] - dt["Jumlah Bayar"].min()) / (dt["Jumlah Bayar"].max() - dt["Jumlah Bayar"].min())
dt.head(10)
# Out:
#   Kode Cust                     Nama Cust Tanggal Bayar  Jumlah Bayar  \
# 0       124  Mini Gifts Distributors Ltd.    2005-03-05      0.841725
# 1       124  Mini Gifts Distributors Ltd.    2004-08-28      0.709282
# 2       124  Mini Gifts Distributors Ltd.    2003-04-11      0.087233
# 3       124  Mini Gifts Distributors Ltd.    2005-04-16      0.694118
# 4       124  Mini Gifts Distributors Ltd.    2004-12-27      0.389183
# 5       124  Mini Gifts Distributors Ltd.    2004-11-02      0.460257
# 6       124  Mini Gifts Distributors Ltd.    2003-08-15      0.928799
# 7       124  Mini Gifts Distributors Ltd.    2004-03-26      0.357620
# 8       124  Mini Gifts Distributors Ltd.    2003-11-25      0.371966
# 9       129               Mini Wheels Co.    2004-12-08      0.214413
#
#   Kode Pegawai     Nama Pegawai                           Email  Pekerjaan
# 0         1165  Leslie Jennings  ljennings@classicmodelcars.com  Sales Rep
# 1         1165  Leslie Jennings  ljennings@classicmodelcars.com  Sales Rep
# 2         1165  Leslie Jennings  ljennings@classicmodelcars.com  Sales Rep
# 3         1165  Leslie Jennings  ljennings@classicmodelcars.com  Sales Rep
# 4         1165  Leslie Jennings  ljennings@classicmodelcars.com  Sales Rep
# 5         1165  Leslie Jennings  ljennings@classicmodelcars.com  Sales Rep
# 6         1165  Leslie Jennings  ljennings@classicmodelcars.com  Sales Rep
# 7         1165  Leslie Jennings  ljennings@classicmodelcars.com  Sales Rep
# 8         1165  Leslie Jennings  ljennings@classicmodelcars.com  Sales Rep
# 9         1165  Leslie Jennings  ljennings@classicmodelcars.com  Sales Rep

# %% [markdown]
# Melakukan transformasi data (label encoding, scalling, binning)

# %%
# split tanggal ke kolom tahun, bulan, hari
import dateutil
dt['Tanggal Bayar'] = dt['Tanggal Bayar'].astype('str')
dt["Tanggal Bayar"] = dt["Tanggal Bayar"].apply(lambda x: dateutil.parser.parse(x))
sp = dt['Tanggal Bayar']
dt['Tahun'] = sp.dt.year
dt['Bulan'] = sp.dt.month
dt['Hari'] = sp.dt.day
dt = dt.drop(columns=['Tanggal Bayar'])
dt.head(10)
# Out:
#   Kode Cust                     Nama Cust  Jumlah Bayar Kode Pegawai  \
# 0       124  Mini Gifts Distributors Ltd.      0.841725         1165
# 1       124  Mini Gifts Distributors Ltd.      0.709282         1165
# 2       124  Mini Gifts Distributors Ltd.      0.087233         1165
# 3       124  Mini Gifts Distributors Ltd.      0.694118         1165
# 4       124  Mini Gifts Distributors Ltd.      0.389183         1165
# 5       124  Mini Gifts Distributors Ltd.      0.460257         1165
# 6       124  Mini Gifts Distributors Ltd.      0.928799         1165
# 7       124  Mini Gifts Distributors Ltd.      0.357620         1165
# 8       124  Mini Gifts Distributors Ltd.      0.371966         1165
# 9       129               Mini Wheels Co.      0.214413         1165
#
#       Nama Pegawai                           Email  Pekerjaan  Tahun  Bulan  \
# 0  Leslie Jennings  ljennings@classicmodelcars.com  Sales Rep   2005      3
# 1  Leslie Jennings  ljennings@classicmodelcars.com  Sales Rep   2004      8
# 2  Leslie Jennings  ljennings@classicmodelcars.com  Sales Rep   2003      4
# 3  Leslie Jennings  ljennings@classicmodelcars.com  Sales Rep   2005      4
# 4  Leslie Jennings  ljennings@classicmodelcars.com  Sales Rep   2004     12
# 5  Leslie Jennings  ljennings@classicmodelcars.com  Sales Rep   2004     11
# 6  Leslie Jennings  ljennings@classicmodelcars.com  Sales Rep   2003      8
# 7  Leslie Jennings  ljennings@classicmodelcars.com  Sales Rep   2004      3
# 8  Leslie Jennings  ljennings@classicmodelcars.com  Sales Rep   2003     11
# 9  Leslie Jennings  ljennings@classicmodelcars.com  Sales Rep   2004     12
#
#    Hari
# 0     5
# 1    28
# 2    11
# 3    16
# 4    27
# 5     2
# 6    15
# 7    26
# 8    25
# 9     8

# %%
# remove kolom email & pekerjaan -> karena sudah tahu itu sales semua
dt = dt.drop(columns=['Email', 'Pekerjaan'])
dt.head(5)
# Out:
#   Kode Cust                     Nama Cust  Jumlah Bayar Kode Pegawai  \
# 0       124  Mini Gifts Distributors Ltd.      0.841725         1165
# 1       124  Mini Gifts Distributors Ltd.      0.709282         1165
# 2       124  Mini Gifts Distributors Ltd.      0.087233         1165
# 3       124  Mini Gifts Distributors Ltd.      0.694118         1165
# 4       124  Mini Gifts Distributors Ltd.      0.389183         1165
#
#       Nama Pegawai  Tahun  Bulan  Hari
# 0  Leslie Jennings   2005      3     5
# 1  Leslie Jennings   2004      8    28
# 2  Leslie Jennings   2003      4    11
# 3  Leslie Jennings   2005      4    16
# 4  Leslie Jennings   2004     12    27

# %%
# gabungkan namacust & kode, begitu pula dg pegawai
dt['Cust'] = dt['Kode Cust'] + '_' + dt['Nama Cust']
dt['Pegawai'] = dt['Kode Pegawai'] + '_' + dt['Nama Pegawai']
dt.head(5)
# Out:
#   Kode Cust                     Nama Cust  Jumlah Bayar Kode Pegawai  \
# 0       124  Mini Gifts Distributors Ltd.      0.841725         1165
# 1       124  Mini Gifts Distributors Ltd.      0.709282         1165
# 2       124  Mini Gifts Distributors Ltd.      0.087233         1165
# 3       124  Mini Gifts Distributors Ltd.      0.694118         1165
# 4       124  Mini Gifts Distributors Ltd.      0.389183         1165
#
#       Nama Pegawai  Tahun  Bulan  Hari                              Cust  \
# 0  Leslie Jennings   2005      3     5  124_Mini Gifts Distributors Ltd.
# 1  Leslie Jennings   2004      8    28  124_Mini Gifts Distributors Ltd.
# 2  Leslie Jennings   2003      4    11  124_Mini Gifts Distributors Ltd.
# 3  Leslie Jennings   2005      4    16  124_Mini Gifts Distributors Ltd.
# 4  Leslie Jennings   2004     12    27  124_Mini Gifts Distributors Ltd.
#
#                 Pegawai
# 0  1165_Leslie Jennings
# 1  1165_Leslie Jennings
# 2  1165_Leslie Jennings
# 3  1165_Leslie Jennings
# 4  1165_Leslie Jennings

# %%
# remove kolom kodeCust,NamaCust,KodePegawai,NamaPegawai -> karena sudah digabung
dt = dt.drop(columns=['Kode Cust', 'Nama Cust', "Kode Pegawai", "Nama Pegawai"])
dt.head(5)
# Out:
#    Jumlah Bayar  Tahun  Bulan  Hari                              Cust  \
# 0      0.841725   2005      3     5  124_Mini Gifts Distributors Ltd.
# 1      0.709282   2004      8    28  124_Mini Gifts Distributors Ltd.
# 2      0.087233   2003      4    11  124_Mini Gifts Distributors Ltd.
# 3      0.694118   2005      4    16  124_Mini Gifts Distributors Ltd.
# 4      0.389183   2004     12    27  124_Mini Gifts Distributors Ltd.
#
#                 Pegawai
# 0  1165_Leslie Jennings
# 1  1165_Leslie Jennings
# 2  1165_Leslie Jennings
# 3  1165_Leslie Jennings
# 4  1165_Leslie Jennings

# %%
# label encoding & scaling
kategori = ["Cust",
            "Pegawai"]

le = preprocessing.LabelEncoder()
for feature in kategori:
    if feature in dt.columns.values:
        dt[feature] = le.fit_transform(dt[feature])
dt.head(5)
# Out:
#    Jumlah Bayar  Tahun  Bulan  Hari  Cust  Pegawai
# 0      0.841725   2005      3     5     5        0
# 1      0.709282   2004      8    28     5        0
# 2      0.087233   2003      4    11     5        0
# 3      0.694118   2005      4    16     5        0
# 4      0.389183   2004     12    27     5        0

# %%
dt.dtypes
# Out:
# Jumlah Bayar    float64
# Tahun             int64
# Bulan             int64
# Hari              int64
# Cust              int32
# Pegawai           int32
# dtype: object

# %%
# bins -> membagi kategori nominal transaksi pembeli -> (Kecil, Normal, Agak Besar, Besar)
dt['Jumlah Bayar'].value_counts(bins=4, sort=False)
# Out:
# (-0.002, 0.25]    131
# (0.25, 0.5]       125
# (0.5, 0.75]        12
# (0.75, 1.0]         5
# Name: Jumlah Bayar, dtype: int64

# %%
cut_labels = ['Kecil', 'Normal', 'Agak Besar', 'Besar']
cut_bins = [-0, 0.25, 0.5, 0.75, 1.0]
dt['Kategori Transaksi'] = pd.cut(dt['Jumlah Bayar'], bins=cut_bins, labels=cut_labels)
dt.head(10)
# Out:
#    Jumlah Bayar  Tahun  Bulan  Hari  Cust  Pegawai Kategori Transaksi
# 0      0.841725   2005      3     5     5        0              Besar
# 1      0.709282   2004      8    28     5        0         Agak Besar
# 2      0.087233   2003      4    11     5        0              Kecil
# 3      0.694118   2005      4    16     5        0         Agak Besar
# 4      0.389183   2004     12    27     5        0             Normal
# 5      0.460257   2004     11     2     5        0             Normal
# 6      0.928799   2003      8    15     5        0              Besar
# 7      0.357620   2004      3    26     5        0             Normal
# 8      0.371966   2003     11    25     5        0             Normal
# 9      0.214413   2004     12     8     7        0              Kecil

# %% [markdown]
# Feature selection

# %%
# Menurut saya tidak perlu pakai feature selection, karena semua data dibutuhkan untuk visualisasi

# %% [markdown]
# Visualisasi Data

# %%
# tahun berapa penjualan terbanyak?
sns.set(style="whitegrid")
sns.barplot(x="Tahun",y="Jumlah Bayar",data=dt, ci=None)

# %%
# siapa sales yg berhasil menjual paling banyak di tahun itu?
ds = dt[dt['Tahun'] == 2005]
sns.set(style="whitegrid")
sns.barplot(x="Pegawai",y="Jumlah Bayar",data=ds, ci=None)

# %%
# siapa sales yg berhasil menjual paling banyak di semua tahun?
sns.set(style="whitegrid")
sns.barplot(x="Pegawai",y="Jumlah Bayar",data=dt, ci=None)

# %%
# list pegawai
mapping = dict(zip(le.classes_, range(0, len(le.classes_))))
print(mapping)
# Out:
# {'1165_Leslie Jennings': 0, '1166_Leslie Thompson': 1, '1188_Julie Firrelli': 2, '1216_Steve Patterson': 3, '1286_Foon Yue Tseng': 4, '1323_George Vanauf': 5, '1337_Loui Bondur': 6, '1370_Gerard Hernandez': 7, '1401_Pamela Castillo': 8, '1501_Larry Bott': 9, '1504_Barry Jones': 10, '1611_Andy Fixter': 11, '1612_Peter Marsh': 12, '1621_Mami Nishi': 13, '1702_Martin Gerard': 14}

# %%
# jumlah kategori transaksi?
gt = dt.groupby(['Kategori Transaksi'])['Jumlah Bayar'].sum().reset_index()
sns.set(style="whitegrid")
sns.barplot(x="Kategori Transaksi",y="Jumlah Bayar",data=gt, ci=None)

# %% [markdown]
# ## Membuat tabel pada database

# %%
# Jumlah Bayar	Tahun	Bulan	Hari	Cust	Pegawai	Kategori Transaksi
cursor.execute("CREATE TABLE IF NOT EXISTS hasil_processing "+
              "(jml_bayar FLOAT NULL, "+
              "tahun INT(10) NULL, " +
              "bulan INT(10) NULL, " +
              "hari INT(10) NULL, " +
              "cust INT(10) NULL, " +
              "pegawai INT(10) NULL, " +
              "kategori VARCHAR(30) NULL)")

for baris in dt.values:
    sql_query = "INSERT INTO hasil_processing VALUES (%s, %s, %s, %s, %s, %s, %s)"
    cursor.execute(sql_query, tuple(baris))
    print(baris, "Telah dimasukkan")
    koneksi.commit()
# Out:
# [0.8417247080809692 2005 3 5 5 0 'Besar'] Telah dimasukkan
# [0.7092816270327181 2004 8 28 5 0 'Agak Besar'] Telah dimasukkan
# [0.08723338708718184 2003 4 11 5 0 'Kecil'] Telah dimasukkan
# [0.6941179895162848 2005 4 16 5 0 'Agak Besar'] Telah dimasukkan
# [0.38918285423149074 2004 12 27 5 0 'Normal'] Telah dimasukkan
# [0.46025671191899237 2004 11 2 5 0 'Normal'] Telah dimasukkan
# [0.9287988327672018 2003 8 15 5 0 'Besar'] Telah dimasukkan
# [0.35761978995932536 2004 3 26 5 0 'Normal'] Telah dimasukkan
# [0.38711495240571964 2005 5 19 9 7 'Normal'] Telah dimasukkan
# [0.49531192218760295 2004 1 30 9 7 'Normal'] Telah dimasukkan
# [0.9668913208934118 2004 12 31 9 7 'Besar'] Telah dimasukkan
# [0.5391484798177985 2005 3 25 9 7 'Agak Besar'] Telah dimasukkan
# [1.0 2005 3 18 9 7 'Besar'] Telah dimasukkan
# [0.4092300925972009 2003 10 26 9 7 'Normal'] Telah dimasukkan
# [0.3311616544318736 2003 2 25 9 7 'Normal'] Telah dimasukkan
# [0.5288791498666722 2003 12 9 9 7 'Agak Besar'] Telah dimasukkan
# [0.2911330909210143 2004 7 9 9 7 'Normal'] Telah dimasukkan
# [0.16222414627113937 2004 8 16 9 7 'Kecil'] Telah dimasukkan
# [0.21363629101623713 2004 5 17 9 7 'Kecil'] Telah dimasukkan
# [0.15376216017364283 2004 3 15 19 7 'Kecil'] Telah dimasukkan
# [0.3527223874839159 2003 11 22 19 7 'Normal'] Telah dimasukkan
# [0.28893327900790233 2005 5 3 33 7 'Normal'] Telah dimasukkan
# [0.033599515119597786 2004 6 21 33 7 'Kecil'] Telah dimasukkan
# [0.29655771551469234 2004 5 4 33 7 'Normal'] Telah dimasukkan
# [0.2777296207907027 2003 11 22 41 7 'Normal'] Telah dimasukkan
# [0.09884364957487227 2005 6 3 41 7 'Kecil'] Telah dimasukkan
# [0.11390314754866808 2003 7 21 41 7 'Kecil'] Telah dimasukkan
# [0.04302736410772529 2004 2 10 44 7 'Kecil'] Telah dimasukkan
# [0.439155531194059 2004 10 22 44 7 'Normal'] Telah dimasukkan
# [0.034255468768885744 2004 7 3 11 8 'Kecil'] Telah dimasukkan
# [0.2308321970691536 2004 4 26 11 8 'Kecil'] Telah dimasukkan
# [0.16686927175008717 2004 12 1 11 8 'Kecil'] Telah dimasukkan
# [0.4462003830494952 2003 2 20 11 8 'Normal'] Telah dimasukkan
# [0.29735402751943874 2003 10 31 37 8 'Normal'] Telah dimasukkan
# [0.4444114413640423 2004 11 2 37 8 'Normal'] Telah dimasukkan
# [0.2786154342497641 2004 9 19 42 8 'Normal'] Telah dimasukkan
# [0.3988547828866193 2004 9 4 42 8 'Normal'] Telah dimasukkan
# [0.3098142192382456 2004 12 5 48 8 'Normal'] Telah dimasukkan
# [0.43108216542997124 2003 3 2 48 8 'Normal'] Telah dimasukkan
# [0.3103972333845778 2003 11 24 48 8 'Normal'] Telah dimasukkan
# [0.3742082571699657 2004 8 9 54 8 'Normal'] Telah dimasukkan
# [0.13622564671701556 2004 3 3 54 8 'Kecil'] Telah dimasukkan
# [0.09590934021284449 2004 12 3 72 8 'Kecil'] Telah dimasukkan
# [0.008465917469788867 2003 4 19 72 8 'Kecil'] Telah dimasukkan
# [0.11513441989214153 2005 2 3 72 8 'Kecil'] Telah dimasukkan
# [0.004288959878505539 2003 8 22 72 8 'Kecil'] Telah dimasukkan
# [0.2945256979168662 2003 5 12 73 8 'Normal'] Telah dimasukkan
# [0.048551527701996625 2004 8 1 73 8 'Kecil'] Telah dimasukkan
# [0.3529734934333118 2004 11 27 73 8 'Normal'] Telah dimasukkan
# [0.3170931132144046 2003 11 18 75 8 'Normal'] Telah dimasukkan
# [0.4266255785286178 2004 7 18 75 8 'Normal'] Telah dimasukkan
# [0.22171643212406272 2003 11 15 84 8 'Kecil'] Telah dimasukkan
# [0.12141683646152067 2003 11 20 84 8 'Kecil'] Telah dimasukkan
# [0.06852022226807894 2005 5 3 84 8 'Kecil'] Telah dimasukkan
# [0.05852399722194178 2004 2 17 90 8 'Kecil'] Telah dimasukkan
# [0.14329274846670204 2003 10 27 90 8 'Kecil'] Telah dimasukkan
# [0.19228132766290038 2005 3 10 25 9 'Kecil'] Telah dimasukkan
# [0.30938252110205905 2003 10 27 25 9 'Normal'] Telah dimasukkan
# [0.28210214324197525 2004 10 21 25 9 'Normal'] Telah dimasukkan
# [0.4367155709862383 2004 11 3 26 9 'Normal'] Telah dimasukkan
# [0.3893201176768467 2004 12 8 26 9 'Normal'] Telah dimasukkan
# [0.39991458048117157 2003 3 27 26 9 'Normal'] Telah dimasukkan
# [0.19483538131341796 2003 10 20 29 9 'Kecil'] Telah dimasukkan
# [0.30650893889501507 2004 6 15 29 9 'Normal'] Telah dimasukkan
# [0.38621709389112424 2004 11 16 40 9 'Normal'] Telah dimasukkan
# [0.2039308202272952 2004 3 28 40 9 'Kecil'] Telah dimasukkan
# [0.38606970925327094 2005 2 15 53 9 'Normal'] Telah dimasukkan
# [0.26856785042516956 2003 10 6 53 9 'Normal'] Telah dimasukkan
# [0.13046417879948102 2004 4 25 53 9 'Kecil'] Telah dimasukkan
# [0.10921159841818306 2004 12 13 59 9 'Kecil'] Telah dimasukkan
# [0.24101562235338134 2003 7 7 59 9 'Kecil'] Telah dimasukkan
# [0.30815534742331585 2003 11 23 59 9 'Normal'] Telah dimasukkan
# [0.3778290510512113 2005 1 27 62 9 'Normal'] Telah dimasukkan
# [0.24342229136604562 2003 8 16 62 9 'Kecil'] Telah dimasukkan
# [0.23236158453709305 2004 5 22 62 9 'Kecil'] Telah dimasukkan
# [0.18118005241773957 2003 12 4 95 9 'Kecil'] Telah dimasukkan
# [0.05600089267244902 2004 1 31 95 9 'Kecil'] Telah dimasukkan
# [0.41491452234704934 2003 2 16 4 10 'Normal'] Telah dimasukkan
# [0.007326823259637948 2003 10 28 4 10 'Kecil'] Telah dimasukkan
# [0.14438065119083357 2004 11 4 4 10 'Kecil'] Telah dimasukkan
# [0.2845869378231724 2004 11 28 4 10 'Normal'] Telah dimasukkan
# [0.08309047350702581 2003 1 28 6 10 'Kecil'] Telah dimasukkan
# [0.19645452117432935 2003 10 18 6 10 'Kecil'] Telah dimasukkan
# [0.2777486921286315 2004 3 24 6 10 'Normal'] Telah dimasukkan
# [0.05730493722644026 2004 11 18 6 10 'Kecil'] Telah dimasukkan
# [0.2960261437930365 2004 12 12 10 10 'Normal'] Telah dimasukkan
# [0.059049964646925544 2003 4 9 10 10 'Kecil'] Telah dimasukkan
# [0.09972770646333497 2004 9 19 18 10 'Kecil'] Telah dimasukkan
# [0.7060494534848814 2003 12 3 18 10 'Agak Besar'] Telah dimasukkan
# [0.14005789823985768 2004 10 3 27 10 'Kecil'] Telah dimasukkan
# [0.26702625060925816 2004 3 1 27 10 'Normal'] Telah dimasukkan
# [0.5070568550878607 2004 11 6 45 10 'Agak Besar'] Telah dimasukkan
# [0.2289649625227298 2003 12 7 45 10 'Kecil'] Telah dimasukkan
# [0.30266071094434654 2003 10 24 52 10 'Normal'] Telah dimasukkan
# [0.264696034240747 2004 9 5 52 10 'Normal'] Telah dimasukkan
# [0.2567490579135471 2004 9 28 79 10 'Normal'] Telah dimasukkan
# [0.2287815263644936 2005 4 18 82 10 'Kecil'] Telah dimasukkan
# [0.40312835186083146 2004 9 30 82 10 'Normal'] Telah dimasukkan
# [0.3784872631484119 2003 5 20 2 11 'Normal'] Telah dimasukkan
# [0.6829359956698026 2004 12 15 2 11 'Agak Besar'] Telah dimasukkan
# [0.058131027285145694 2003 5 31 2 11 'Kecil'] Telah dimasukkan
# [0.3703795187883209 2004 3 10 2 11 'Normal'] Telah dimasukkan
# [0.2213975727372882 2005 2 9 47 11 'Kecil'] Telah dimasukkan
# [0.3172846630558825 2003 11 13 47 11 'Normal'] Telah dimasukkan
# [0.3424415980007885 2003 9 28 47 11 'Normal'] Telah dimasukkan
# [0.2445235774852149 2005 4 30 47 11 'Kecil'] Telah dimasukkan
# [0.19571600870690223 2003 8 3 49 11 'Kecil'] Telah dimasukkan
# [0.29436175132765374 2004 8 2 49 11 'Normal'] Telah dimasukkan
# [0.2611427428582231 2005 1 3 49 11 'Normal'] Telah dimasukkan
# [0.19507201646692923 2003 11 15 61 11 'Kecil'] Telah dimasukkan
# [0.07700362179763587 2003 10 17 61 11 'Kecil'] Telah dimasukkan
# [0.17412516301602501 2005 3 1 61 11 'Kecil'] Telah dimasukkan
# [0.0736059960286448 2004 7 28 89 11 'Kecil'] Telah dimasukkan
# [0.29184316367398616 2003 12 10 89 11 'Normal'] Telah dimasukkan
# [0.3192778688080991 2004 9 16 17 12 'Normal'] Telah dimasukkan
# [0.3642413919466926 2004 7 7 17 12 'Normal'] Telah dimasukkan
# [0.18283992798729712 2004 2 28 17 12 'Kecil'] Telah dimasukkan
# [0.6223670156860919 2005 5 23 58 12 'Agak Besar'] Telah dimasukkan
# [0.3066964737179816 2004 6 24 58 12 'Normal'] Telah dimasukkan
# [0.01894210452046752 2003 7 5 58 12 'Kecil'] Telah dimasukkan
# [0.32475761626008887 2004 12 24 58 12 'Normal'] Telah dimasukkan
# [0.16398498282701301 2003 12 16 68 12 'Kecil'] Telah dimasukkan
# [0.2996783886526208 2004 5 15 68 12 'Normal'] Telah dimasukkan
# [0.28790292488243313 2004 7 25 78 12 'Normal'] Telah dimasukkan
# [0.2597626638911736 2004 4 14 78 12 'Normal'] Telah dimasukkan
# [0.24791317321718329 2005 5 25 97 12 'Kecil'] Telah dimasukkan
# [0.2631676505274354 2003 7 16 97 12 'Normal'] Telah dimasukkan
# [0.43120085941471237 2004 12 31 97 12 'Normal'] Telah dimasukkan
# [0.36607516800552203 2003 4 22 13 13 'Normal'] Telah dimasukkan
# [0.016699047512139784 2004 8 11 13 13 'Kecil'] Telah dimasukkan
# [0.8793522068758363 2003 12 26 13 13 'Besar'] Telah dimasukkan
# [0.024262338632851065 2005 3 27 13 13 'Kecil'] Telah dimasukkan
# [0.12185731745070079 2004 4 17 23 13 'Kecil'] Telah dimasukkan
# [0.38947469588953276 2004 1 19 23 13 'Normal'] Telah dimasukkan
# [0.3752816054519936 2003 12 9 34 13 'Normal'] Telah dimasukkan
# [0.1675332554363978 2003 12 2 74 13 'Kecil'] Telah dimasukkan
# [0.12720406741450288 2004 11 19 74 13 'Kecil'] Telah dimasukkan
# [0.42145791511966474 2003 3 9 74 13 'Normal'] Telah dimasukkan
# [0.2789792116561341 2005 2 14 76 13 'Normal'] Telah dimasukkan
# [0.17919077803781527 2004 6 21 76 13 'Kecil'] Telah dimasukkan
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-53-84a9afb32ce4> in <module>
#      11 for baris in dt.values:
#      12     sql_query = "INSERT INTO hasil_processing VALUES (%s, %s, %s, %s, %s, %s, %s)"
# ---> 13     cursor.execute(sql_query, tuple(baris))
#      14     print(baris, "Telah dimasukkan")
#      15     koneksi.commit()
#
# ~\AppData\Roaming\Python\Python38\site-packages\mysql\connector\cursor.py in execute(self, operation, params, multi)
#     567
#     568         try:
# --> 569             self._handle_result(self._connection.cmd_query(stmt))
#     570         except errors.InterfaceError:
#     571             if self._connection._have_next_result:  # pylint: disable=W0212
#
# ~\AppData\Roaming\Python\Python38\site-packages\mysql\connector\connection.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     649             query = query.encode('utf-8')
#     650         try:
# --> 651             result = self._handle_result(self._send_cmd(ServerCmd.QUERY, query))
#     652         except errors.ProgrammingError as err:
#     653             if err.errno == 3948 and \
#
# ~\AppData\Roaming\Python\Python38\site-packages\mysql\connector\connection.py in _handle_result(self, packet)
#     536             return self._handle_eof(packet)
#     537         elif packet[4] == 255:
# --> 538             raise errors.get_exception(packet)
#     539
#     540         # We have a text result set
#
# ProgrammingError: 1054 (42S22): Unknown column 'nan' in 'field list'

# %% [markdown]
# ## Export to File

# %%
from pandas import DataFrame, read_csv
dt.to_csv("data_hasil_ekspor.csv", index=False)

# %%
data_ekspor = read_csv("data_hasil_ekspor.csv")
data_ekspor.head(10)
# Out:
#    Jumlah Bayar  Tahun  Bulan  Hari  Cust  Pegawai Kategori Transaksi
# 0      0.841725   2005      3     5     5        0              Besar
# 1      0.709282   2004      8    28     5        0         Agak Besar
# 2      0.087233   2003      4    11     5        0              Kecil
# 3      0.694118   2005      4    16     5        0         Agak Besar
# 4      0.389183   2004     12    27     5        0             Normal
# 5      0.460257   2004     11     2     5        0             Normal
# 6      0.928799   2003      8    15     5        0              Besar
# 7      0.357620   2004      3    26     5        0             Normal
# 8      0.371966   2003     11    25     5        0             Normal
# 9      0.214413   2004     12     8     7        0              Kecil
